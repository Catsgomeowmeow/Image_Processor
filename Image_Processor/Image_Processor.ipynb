# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import sys
import glob
import timeit
import os.path
# from Ipython.display import html
from PIL import Image

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
#Loads the image file

for file in glob.glob("*.jpg"):
     print(file)

while True:
    image = input("file name (no extension): ")
    x = os.path.isfile(image+'.jpg')
#     print (x)
    if x == True:
        
        break
    else:
        print("invalid File")
        

#Converts the image to black and white (python uses a  high contrast version)
img_src = Image.open(image +'.jpg').convert('L')
#turns image into an array
im = np.array(img_src)
sizeim = im.shape[0]
sizeim = sizeim /2
sizeim = int(sizeim)


data = im[sizeim,:]
y,x,_ = plt.hist(data)
print (x.max(),x.min())
gmax = int(x.max())
gmin = int(x.min())

#to get best image take the first peak of the mininmum
# Out:
# cylinder.JPG
# DSC00015.JPG
# DSC00016.JPG
# DSC00017.JPG
# Fracture.JPG
# hand2.jpg
# Small.JPG
# step.JPG
# tea.jpg
# test.JPG
# white-2.jpg
# white.JPG
# file name (no extension): step
# 221.0 38.0

# %%
while True:
    inputmin = input("Please give a min, leave blank for min from historgram: ")
    if inputmin == '':
        inputmin = gmin
        break
    else:
        inputmin = int(inputmin)
        break
while True:
    inputmax = input("please give a max, leave blank for max  from historgram: ")
    if inputmax == '':
        inputmax = gmax
        break
    else:
        inputmax = int(inputmax)
        break
print (inputmax)
print (inputmin)
# print (type(gmin))
plt.imshow(im, vmax = inputmax, vmin = inputmin)
print (gmax,gmin)
plt.show()
# Out:
# Please give a min, leave blank for min from historgram: 150
# please give a max, leave blank for max  from historgram: 225
# 225
# 150
# 221 38

# %%
#cross section plot at the middle 
axes = plt.gca()
axes.set_ylim([inputmin,inputmax])


plt.plot(data)
